# %%
import numpy as np
import pandas as pd
import h5py
import vaex
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import PathPatch
from matplotlib.path import Path

from astropy import units as u
from astropy.io import ascii, fits
from astropy.table import Table, vstack
from astropy.coordinates import SkyCoord,CartesianRepresentation,match_coordinates_sky

import functions as fn 

np.random.seed(0)

# %%
box = 'rogue' # the boxes are 'rogue', 'elektra' 'storm' and 'MM' (for Marvelous Massive)
num = 5 # number of our galaxy within the box
D = 2000 # 2000 kpc is 2 Mpc
mlim_str = '26p5' # 26.5 is the depth of the yr 10 survey, i had to do p instead of . because ananke got mad at there being a decimal in the name of one of the galaxies. weird
name = f'{box}_4096_{num}_data_{D}_{mlim_str}' 

# this is the path to the galaxy, change this to be where you put your data! I used an f-string and some {} to put my variables in here so it is easy to read in different catalogs
dwarfcatpath = f'../..//data/raw/{box}_{num}/survey.{name}.0.h5'
# these are read in with vaex, which i convert to a pandas dataframe since i am more familar with them 
vdwarfcat = vaex.open(dwarfcatpath)
dwarfcat = pd.DataFrame(vdwarfcat,columns=vdwarfcat.column_names)

# %%
size_kpc = 40 # length of one edge of the plot in kpc - edge length of the plots based on the first plot in this notebook
pdist = (size_kpc/D) * (180/np.pi) # converting the above into degrees (on the sky) instead of kpc
year = 10
mlim = '25'
c1='px'
c2='py'
edgelength = 10 # size of the bg field that I generated, this is (unecessarily) huge, so if you want a smaller one I can make one 
plotdir_s = f'{box}_4096_{num}' # folder where you want your plots to go if you are saving them
bgcatpath = f"../../data/matched-filter/bgcats/bgr{mlim}g{mlim}_for_mf_{int(edgelength)}deg.fits"

# %% [markdown]
# ## Matched filter detection

# %% [markdown]
# We have reached our destination of using the matched filter. Again, a function for this has been defined, but I reccomend reading through that script (after or during when you read the paper I sent [here](https://iopscience.iop.org/article/10.1086/340957/pdf)) to understand how this works. It is hard to parse, but with practice and time you will become an expert.

# %%
gal_name = f"{box}_{num}"

# %%
age = '10'
mh = '-2'

from matched_filter_ani import matched_filter_ani as mf

iso_info = 'parsec' # there are a lot of isochone models out there, parsec is the one I like to use
rmaglim=26

# the number of pixels (bins in ra/dec on the sky) is the thing that slows this code down the most (look at the nested loop in the matched fitler function to see why)
# i paramaterize this function based on number of pixels instead of the size of the pixel itself so I have a better idea of how long it should take to run
# 2000-3000 works best for the close + deep images or those with big features, closer to 1000 is better for the distant and shallow ones. 
# this is because each bin on the sky needs enough real stars to get weighted highly, and when the galaxy is far or the observations are shallow, we detect fewer stars
numpix = 100
pix = (np.round(np.sqrt((2*pdist*60)**2 / numpix),2))
catalog=f'../../data/matched-filter/catalogs/' + name + f'_{c1}{c2}_formf_bg{edgelength}deg.fits'
field = name+f'_mfmag{rmaglim}_{iso_info}{age}{mh}{c1}{c2}_{np.round(pdist*60,0)}'
plotdir_path = f"../plots/{plotdir_s}/"

mf(gal_name,
    field=field,
    catalog=catalog,
    signal_file=f"../../data/signals/{iso_info}_{D}_{age}{mh}_signal_cmd_gr.txt",
    plot=False, rmaglim = rmaglim, pix=pix, pdist=pdist*60) 


# this will take a few minutes to run, especially in the notebook format. On my machine, it took about 10 minutes, and I am using a remote machine much more powerful than my laptop
# I recommend runnning the function in the terminal for actual research purposes - speeds things up and is easier to iterate if you change the functions
# the runtime will vary as well based on the number of pixels you choose to use and other knobs you may want to turn
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 19
#      16 field = name+f'_mfmag{rmaglim}_{iso_info}{age}{mh}{c1}{c2}_{np.round(pdist*60,0)}'
#      17 plotdir_path = f"../plots/{plotdir_s}/"
# ---> 19 mf(gal_name,
#      20     field=field,
#      21     catalog=catalog,
#      22     signal_file=f"/home/otteleno/MAP/matched_filter_starters/signal_files/{iso_info}_{D}_{age}{mh}_signal_cmd_gr.txt",
#      23     plot=False, rmaglim = rmaglim, pix=pix, pdist=pdist*60)
#      26 # this will take a few minutes to run, especially in the notebook format. On my machine, it took about 10 minutes, and I am using a remote machine much more powerful than my laptop
#      27 # I recommend runnning the function in the terminal for actual research purposes - speeds things up and is easier to iterate if you change the functions
#      28 # the runtime will vary as well based on the number of pixels you choose to use and other knobs you may want to turn
#
# File ~/MAP/code/matched-filter/matched_filter_ani.py:185, in matched_filter_ani(plotdir, field, catalog, signal_file, rmaglim, plot, RAkey, DECkey, gmagkey, rmagkey, agmagkey, armagkey, pix, pdist)
#     183     backcmd = mk_norm_backcmd(field, catalog,rmaglim=rmaglim,plot=True,pix=pix)
#     184 else:
# --> 185     objcmd = mk_norm_objcmd_gd(field, signal_file, rmaglim=rmaglim)
#     186     backcmd = mk_norm_backcmd(field, catalog, rmaglim=rmaglim,pix=pix)
#     188 yo = (backcmd < 1.0e-7) #Bad indices?
#
# File ~/MAP/code/matched-filter/matched_filter_ani.py:129, in mk_norm_objcmd_gd(field, sourcefile, rmaglim, plot)
#     122 def mk_norm_objcmd_gd(field, sourcefile, rmaglim = 26.0, plot=False):
#     123     '''
#     124     This is the signal file. You can create a signal file by populating a
#     125     stellar population from an isochrone and its luminosity function.
#     126     This is basically the cmd space which the code will try to match.
#     127     '''
# --> 129     sourcefile = Table.read(sourcefile, format='ascii')
#     130     gminr_mock = sourcefile['grcol']
#     131     r_mock = sourcefile['rmag']
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop("units", None)
#      60 descriptions = kwargs.pop("descriptions", None)
# ---> 62 out = self.registry.read(cls, *args, **kwargs)
#      64 # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#      65 # guaranteed to be the same as the desired output `cls`.  If so,
#      66 # try coercing to desired class without copying (io.registry.read
#      67 # would normally do a copy).  The normal case here is swapping
#      68 # Table <=> QTable.
#      69 if cls is not out.__class__:
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/io/registry/core.py:221, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     218         kwargs.update({"filename": path})
#     220 reader = self.get_reader(format, cls)
# --> 221 data = reader(*args, **kwargs)
#     223 if not isinstance(data, cls):
#     224     # User has read with a subclass where only the parent class is
#     225     # registered.  This returns the parent class, so try coercing
#     226     # to desired subclass.
#     227     try:
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/io/ascii/connect.py:19, in io_read(format, filename, **kwargs)
#      17     format = re.sub(r"^ascii\.", "", format)
#      18     kwargs["format"] = format
# ---> 19 return read(filename, **kwargs)
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/utils/decorators.py:603, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     600             msg += f"\n        Use {alternative} instead."
#     601         warnings.warn(msg, warning_type, stacklevel=2)
# --> 603 return function(*args, **kwargs)
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/utils/decorators.py:603, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     600             msg += f"\n        Use {alternative} instead."
#     601         warnings.warn(msg, warning_type, stacklevel=2)
# --> 603 return function(*args, **kwargs)
#
#     [... skipping similar frames: deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper at line 603 (2 times)]
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/utils/decorators.py:603, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     600             msg += f"\n        Use {alternative} instead."
#     601         warnings.warn(msg, warning_type, stacklevel=2)
# --> 603 return function(*args, **kwargs)
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/io/ascii/ui.py:409, in read(table, guess, **kwargs)
#     403             new_kwargs["guess_html"] = _probably_html(table)
#     405 # Get the table from guess in ``dat``.  If ``dat`` comes back as None
#     406 # then there was just one set of kwargs in the guess list so fall
#     407 # through below to the non-guess way so that any problems result in a
#     408 # more useful traceback.
# --> 409 dat = _guess(table, new_kwargs, format, fast_reader)
#     410 if dat is None:
#     411     guess = False
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/io/ascii/ui.py:616, in _guess(table, read_kwargs, format, fast_reader)
#     613 reader = get_reader(**guess_kwargs)
#     615 reader.guessing = True
# --> 616 dat = reader.read(table)
#     617 _read_trace.append(
#     618     {
#     619         "kwargs": copy.deepcopy(guess_kwargs),
#    (...)
#     623     }
#     624 )
#     625 return dat
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/io/ascii/core.py:1425, in BaseReader.read(self, table)
#    1422 self.lines = self.inputter.get_lines(table, newline=newline)
#    1424 # Set self.data.data_lines to a slice of lines contain the data rows
# -> 1425 self.data.get_data_lines(self.lines)
#    1427 # Extract table meta values (e.g. keywords, comments, etc).  Updates self.meta.
#    1428 self.header.update_meta(self.lines, self.meta)
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/io/ascii/core.py:830, in BaseData.get_data_lines(self, lines)
#     826 def get_data_lines(self, lines):
#     827     """
#     828     READ: Set ``data_lines`` attribute to lines slice comprising table data values.
#     829     """
# --> 830     data_lines = self.process_lines(lines)
#     831     start_line = _get_line_index(self.start_line, data_lines)
#     832     end_line = _get_line_index(self.end_line, data_lines)
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/io/ascii/core.py:822, in BaseData.process_lines(self, lines)
#     820 if self.comment:
#     821     re_comment = re.compile(self.comment)
# --> 822     return [x for x in nonblank_lines if not re_comment.match(x)]
#     823 else:
#     824     return list(nonblank_lines)
#
# File ~/.conda/envs/conda-env-MAP/lib/python3.10/site-packages/astropy/io/ascii/core.py:822, in <listcomp>(.0)
#     820 if self.comment:
#     821     re_comment = re.compile(self.comment)
# --> 822     return [x for x in nonblank_lines if not re_comment.match(x)]
#     823 else:
#     824     return list(nonblank_lines)
#
# KeyboardInterrupt:
