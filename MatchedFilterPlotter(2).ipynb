# %%
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
hdul = fits.open('/home/otteleno/MAP/matched_filter_plots/storm_2_data_hd.fits')

# %%
segmented_hdul = fits.open('/home/otteleno/MAP/matched_filter_plots/storm_2_data_hd_segmented.fits')

# %%
data=hdul[0].data

# %%
segmented_data=segmented_hdul[2].data

# %%
hdul.info()
# Out:
# Filename: /home/otteleno/MAP/matched_filter_plots/storm_2_data_hd.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (89, 89)   float64

# %%
segmented_hdul.info()
# Out:
# Filename: /home/otteleno/MAP/matched_filter_plots/storm_2_data_hd_segmented.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  SEGMENT-CONFIG    1 PrimaryHDU      48   ()
#   1  INPUT-NO-SKY    1 ImageHDU         8   (89, 89)   float32
#   2  CLUMPS        1 ImageHDU        10   (89, 89)   int32
#   3  OBJECTS       1 ImageHDU        10   (89, 89)   int32

# %%
plt.figure(figsize=(8,8))
plt.imshow(data, extent=[-60,60,-60,60], \
            cmap = 'gray_r', vmin = -15, vmax = 30)
plt.colorbar(label = 'intensity')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(segmented_data, extent=[-60,60,-60,60], \
            cmap = 'gray_r', vmin = -15, vmax = 30)
plt.colorbar(label = 'Group')
plt.show()
