# %%
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
hdul = fits.open('/home/giantsid/MAP/matched_filter_plots/storm_2_data.fits')

# %%
hdul2 = fits.open('/home/giantsid/MAP/matched_filter_plots/storm_2_data_segmented.fits')

# %%
hdul.info()
# Out:
# Filename: /home/giantsid/MAP/matched_filter_plots/storm_2_data.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (45, 45)   float64

# %%
hdul2.info()
# Out:
# Filename: /home/giantsid/MAP/matched_filter_plots/storm_2_data_segmented.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  SEGMENT-CONFIG    1 PrimaryHDU      48   ()
#   1  INPUT-NO-SKY    1 ImageHDU         8   (45, 45)   float32
#   2  CLUMPS        1 ImageHDU        10   (45, 45)   int32
#   3  OBJECTS       1 ImageHDU        10   (45, 45)   int32

# %%
image_data=hdul[0].data

# %%
image_data2=hdul2[3].data

# %%
plt.figure(figsize=(8,8))
plt.imshow(image_data, extent=[-60,60,-60,60], \
            cmap = 'gray', vmin = -15, vmax = 30)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(image_data2, extent=[-60,60,-60,60], \
            cmap = 'gray', vmin = -15, vmax = 30)
plt.colorbar()
plt.show()
