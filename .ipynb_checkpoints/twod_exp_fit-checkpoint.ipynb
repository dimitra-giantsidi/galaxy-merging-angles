# %% [markdown]
# # Fit a 2-D Exponential to a 2-D histogram of star counts from Match Filter
# ## Charlotte Christensen, June 18, 2026

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
hdul = fits.open('/home/giantsid/MAP/matched_filter_plots/storm_2_data.fits')

# %%
hdul.info()
# Out:
# Filename: /home/giantsid/MAP/matched_filter_plots/storm_2_data.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (45, 45)   float64

# %%
image_data=hdul[0].data

# %%
# 1. Define the 2-D exponential model function
# The first argument must accept the combined X and Y coordinate array
def exponential_2d(coords, A, h, q, theta, C):
    # Parameters: A is amplitude, h is scale length, q is axis ratio (ie., minor/major; related to orientation), 
    # theta is rotation angle in viewing plane, C is offset from background (should be about zero)
    # theta = 0 means major axis is along x-axis, theta = pi/2 means major axis is along y-axis
    x, y = coords
    x_prime = x * np.cos(theta) + y * np.sin(theta)
    y_prime = -x * np.sin(theta) + y * np.cos(theta)
    r = np.sqrt(x_prime**2 + y_prime**2/q**2)
    return A * np.exp(-r/h) + C

# %%
# 2. Generate synthetic mock data with noise
x_line = np.linspace(-2, 2, 40)
y_line = np.linspace(-2, 2, 40)
X, Y = np.meshgrid(x_line, y_line)

# True parameters: A=2.5, kx=0.8, ky=0.5, C=1.2
true_params = [2.5, 0.8, 0.5, 1.2, np.pi/6]  # A, kx, ky, C, theta
Z_clean = exponential_2d((X, Y), *true_params)

# Add random Gaussian noise
np.random.seed(42)
noise = np.random.normal(0, 0.2, size=Z_clean.shape)
Z_noisy = Z_clean + noise

# 3. Flatten the arrays to 1-D for curve_fit
x_flat = X.ravel()
y_flat = Y.ravel()
z_flat = Z_noisy.ravel()

# Combine independent variables into an (2, N) shaped array
independent_vars = np.vstack((x_flat, y_flat))

# %%
# 4. Provide a sensible initial guess (p0) to prevent divergence
# Form: [A, kx, ky, C]
initial_guess = [1.0, 0.1, 0.1, 1.0, 0]

# 5. Perform the optimization
fitted_params, covariance = curve_fit(
    f=exponential_2d, 
    xdata=independent_vars, 
    ydata=z_flat, 
    p0=initial_guess
)

# %%
# 6. Extract and view results
A_fit, kx_fit, ky_fit, C_fit, theta_fit = fitted_params
print("Fitted Parameters:")
print(f"A  = {A_fit:.4f} (True: {true_params[0]})")
print(f"kx = {kx_fit:.4f} (True: {true_params[1]})")
print(f"ky = {ky_fit:.4f} (True: {true_params[2]})")
print(f"C  = {C_fit:.4f} (True: {true_params[3]})")
print(f"theta = {theta_fit:.4f} (True: {true_params[4]})")
# Out:
# Fitted Parameters:
# A  = 2.5459 (True: 2.5)
# kx = 0.7803 (True: 0.8)
# ky = 0.5013 (True: 0.5)
# C  = 1.1918 (True: 1.2)
# theta = 0.5367 (True: 0.5235987755982988)

# %%
Z_fitted = exponential_2d((X, Y), *fitted_params)

# %%
import matplotlib.pyplot as plt

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the original noisy data as an image
im = ax.imshow(image_data, origin='lower', extent=[-60,60,-60,60], 
               cmap='viridis', aspect='auto')

# Overlay contours of the fitted result
contours = ax.contour(X, Y, Z_fitted, colors='white', linewidths=2, levels=8, alpha=0.8)
ax.clabel(contours, inline=True, fontsize=8, fmt='%.2f')

# Add colorbar
cbar = plt.colorbar(im, ax=ax)
cbar.set_label('Value', rotation=270, labelpad=20)

# Labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Original Data (Image) with Fitted Model Contours (White)')

plt.tight_layout()
plt.show()
