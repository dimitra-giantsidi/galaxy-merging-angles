# %%
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
hdul = fits.open('/home/otteleno/MAP/matched_filter_plots/rogue_5_data_segmented.fits')

# %%
hdul.info()
# Out:
# Filename: /home/otteleno/MAP/matched_filter_plots/rogue_5_data_segmented.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  SEGMENT-CONFIG    1 PrimaryHDU      48   ()
#   1  INPUT-NO-SKY    1 ImageHDU         8   (45, 45)   float32
#   2  CLUMPS        1 ImageHDU        10   (45, 45)   int32
#   3  OBJECTS       1 ImageHDU        10   (45, 45)   int32

# %%
image_data=hdul[1].data

# %%
plt.figure(figsize=(8,8))
plt.imshow(image_data, cmap='gray', origin='lower')
plt.colorbar(label = 'intensity')
plt.show()
