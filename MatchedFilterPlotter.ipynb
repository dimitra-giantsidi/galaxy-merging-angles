# %%
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np

# %%
matched_hdul = fits.open('/home/otteleno/MAP/automated_data/matched_filter_catalogs/storm_2/storm_2_d=0.0_a=0.0.fits')

# %%
unmatched_hdul = fits.open('/home/otteleno/MAP/automated_data/background_added_catalogs/storm_2/storm_2_d=0.0_a=0.0.fits')

# %%
data=matched_hdul[0].data

# %%
unmatched_data=unmatched_hdul[1].data
